# %%
import pandas as pd

df = pd.read_csv('animal-service-intake-and-outcome-1.csv')

df.tail()
# Out:
#        AnimalID AnimalType           IntakeDate  IntakeType IntakeSubtype  \
# 150837  A591486        DOG  2016-06-02 14:48:00   OWNER SUR           OTC
# 150838  A523743        DOG  2014-04-16 12:05:00       STRAY           OTC
# 150839  A369002        DOG  2013-01-23 13:59:00       STRAY           OTC
# 150840  A439252        CAT  2016-08-01 17:43:00       STRAY         FIELD
# 150841  A424601        CAT  2013-07-19 13:02:00  ET REQUEST          SICK
#
#           PrimaryColor         PrimaryBreed SecondaryBreed         Gender  \
# 150837  YELLOW BRINDLE            GREYHOUND            MIX  NEUTERED MALE
# 150838           CREAM        CAIRN TERRIER            NaN  SPAYED FEMALE
# 150839           BLACK   MINIATURE PINSCHER            NaN  NEUTERED MALE
# 150840     BLACK TABBY  DOMESTIC MEDIUMHAIR            NaN  SPAYED FEMALE
# 150841            GRAY   DOMESTIC SHORTHAIR            NaN  SPAYED FEMALE
#
#        SecondaryColor             ...             IntakeInternalStatus  \
# ...

# %%
df.loc[86652]
df = df[pd.notnull(df['OutcomeDate'])]
df = df[pd.notnull(df['IntakeDate'])]

# %%
from datetime import datetime
FMT = '%Y-%m-%d %H:%M:%S'
df['TimeInShelter'] = df.apply(lambda x: datetime.strptime(x['OutcomeDate'], FMT) - datetime.strptime(x['IntakeDate'], FMT), axis=1)

# %%
df.head()
# Out:
#   AnimalID AnimalType           IntakeDate  IntakeType IntakeSubtype  \
# 0  A366370        CAT  2008-11-07 10:50:00       STRAY           OTC
# 1  A366531        CAT  2008-11-10 10:20:00       STRAY           OTC
# 2  A532367       BIRD  2014-07-23 23:21:00  CONFISCATE       CRUELTY
# 3  A532474      OTHER  2014-07-24 18:29:00  ET REQUEST           NaN
# 4  A281756        DOG  2006-09-11 18:10:00   OWNER SUR           OTC
#
#   PrimaryColor        PrimaryBreed      SecondaryBreed         Gender  \
# 0        WHITE  DOMESTIC SHORTHAIR                 NaN  NEUTERED MALE
# 1        BLACK  DOMESTIC SHORTHAIR  DOMESTIC SHORTHAIR        UNKNOWN
# 2          RED             CHICKEN                 NaN           MALE
# 3        BROWN                 BAT                 NaN        UNKNOWN
# 4        WHITE    PIT BULL TERRIER                 NaN           MALE
#
#   SecondaryColor        ...        IntakeAsilomarStatus  \
# 0          BROWN        ...                     HEALTHY
# ...
